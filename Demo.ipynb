# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Outlet_Sales  Item_Fat_Content_LF  Item_Fat_Content_Low Fat  \
# 0          3735.1380                    0                         1
# 1           443.4228                    0                         0
# 2          2097.2700                    0                         1
# 3           732.3800                    0                         0
# 4           994.7052                    0                         1
#
#    Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Item_Weight                      8523 non-null   float64
#  1   Item_Visibility                  8523 non-null   float64
#  2   Item_MRP                         8523 non-null   float64
#  3   Outlet_Establishment_Year        8523 non-null   int64
#  4   Item_Outlet_Sales                8523 non-null   float64
#  5   Item_Fat_Content_LF              8523 non-null   int64
#  6   Item_Fat_Content_Low Fat         8523 non-null   int64
#  7   Item_Fat_Content_Regular         8523 non-null   int64
#  8   Item_Fat_Content_low fat         8523 non-null   int64
#  9   Item_Fat_Content_reg             8523 non-null   int64
#  10  Item_Type_Baking Goods           8523 non-null   int64
#  11  Item_Type_Breads                 8523 non-null   int64
# ...

# %%
x = df.drop('Item_Outlet_Sales',axis=1)
x
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# ...

# %%
y = df[['Item_Outlet_Sales']]
y
# Out:
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# 3              732.3800
# 4              994.7052
# ...                 ...
# 8518          2778.3834
# 8519           549.2850
# 8520          1193.1136
# 8521          1845.5976
# 8522           765.6700
#
# [8523 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)

# %%
LiModel = LinearRegression()
LiModel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LiModel.predict(x_test)
y_pred[0:5]
# Out:
# array([[ 529.9984577 ],
#        [1222.77259157],
#        [3203.40348821],
#        [1478.47827306],
#        [ 790.82695774]])

# %%
y_test[0:5]
# Out:
#       Item_Outlet_Sales
# 1070           952.7598
# 6305          1133.8574
# 8504          4138.6128
# 5562          1657.1762
# 1410           679.1160

# %%
Accuracy = r2_score(y_test,y_pred)
Accuracy
# Out:
# 0.5619682897599159

# %%
import pickle

# %%
with open('LiModel.pkl','wb') as file:
    pickle.dump(LiModel,file)

# %%
with open('LiModel.pkl','rb') as file:
    pic_model = pickle.load(file)

# %%
pic_model.predict(x_test)
# Out:
# array([[ 529.9984577 ],
#        [1222.77259157],
#        [3203.40348821],
#        ...,
#        [ 648.68239927],
#        [2288.33596459],
#        [ 999.29867625]])

# %% [raw]
# array([[ 529.9984577 ],
#        [1222.77259157],
#        [3203.40348821],
#        [1478.47827306],
#        [ 790.82695774]])

# %%
li_col = [i for i in x_test.columns]
li_col
# Out:
# ['Item_Weight',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Fat_Content_LF',
#  'Item_Fat_Content_Low Fat',
#  'Item_Fat_Content_Regular',
#  'Item_Fat_Content_low fat',
#  'Item_Fat_Content_reg',
#  'Item_Type_Baking Goods',
#  'Item_Type_Breads',
#  'Item_Type_Breakfast',
#  'Item_Type_Canned',
#  'Item_Type_Dairy',
#  'Item_Type_Frozen Foods',
#  'Item_Type_Fruits and Vegetables',
#  'Item_Type_Hard Drinks',
#  'Item_Type_Health and Hygiene',
#  'Item_Type_Household',
#  'Item_Type_Meat',
#  'Item_Type_Others',
#  'Item_Type_Seafood',
#  'Item_Type_Snack Foods',
#  'Item_Type_Soft Drinks',
#  'Item_Type_Starchy Foods',
#  'Outlet_Identifier_OUT010',
#  'Outlet_Identifier_OUT013',
#  'Outlet_Identifier_OUT017',
#  'Outlet_Identifier_OUT018',
#  'Outlet_Identifier_OUT019',
#  'Outlet_Identifier_OUT027',
#  'Outlet_Identifier_OUT035',
#  'Outlet_Identifier_OUT045',
#  'Outlet_Identifier_OUT046',
#  'Outlet_Identifier_OUT049',
#  'Outlet_Size_High',
# ...

# %%
len(li_col)
# Out:
# 45

# %%
user_df = pd.DataFrame(columns = li_col)

# %%
user_df
# Out:
# Empty DataFrame
# ...

# %%
user_df.loc[0] = np.zeros(len(li_col))

# %%
user_df.to_csv('Testing_Df.csv',index=False)

# %%
user_df
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0          0.0              0.0       0.0                        0.0
#
#    Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                  0.0                       0.0                       0.0
#
#    Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Baking Goods  \
# 0                       0.0                   0.0                     0.0
#
#    ...  Outlet_Size_High  Outlet_Size_Medium  Outlet_Size_Small  \
# 0  ...               0.0                 0.0                0.0
#
#    Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 0                          0.0                          0.0
#
#    Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 0                          0.0                        0.0
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                            0.0                            0.0
#
# ...

# %%
user_df['Item_Weight']                  = 9.30
user_df['Item_Visibility']              = 0.016047
user_df['Item_MRP']                     = 249.8092
user_df['Outlet_Establishment_Year']    = 1999
Location = 'Item_Fat_Content_Regular'
user_df[Location] = 1

# %%
user_df
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0          9.3         0.016047  249.8092                       1999
#
#    Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                  0.0                       0.0                         1
#
#    Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Baking Goods  \
# 0                       0.0                   0.0                     0.0
#
#    ...  Outlet_Size_High  Outlet_Size_Medium  Outlet_Size_Small  \
# 0  ...               0.0                 0.0                0.0
#
#    Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 0                          0.0                          0.0
#
#    Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 0                          0.0                        0.0
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                            0.0                            0.0
#
# ...

# %%
res = pic_model.predict(user_df)[0][0]
user_df.loc[0] = np.zeros(len(li_col))
res
# Out:
# 3496.7702859450146

# %%
pic_model.predict(user_df)[0][0]
# Out:
# 3496.7702859450146

# %%
user_df
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0          0.0              0.0       0.0                          0
#
#    Item_Fat_Content_LF  Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  \
# 0                  0.0                       0.0                         0
#
#    Item_Fat_Content_low fat  Item_Fat_Content_reg  Item_Type_Baking Goods  \
# 0                       0.0                   0.0                     0.0
#
#    ...  Outlet_Size_High  Outlet_Size_Medium  Outlet_Size_Small  \
# 0  ...               0.0                 0.0                0.0
#
#    Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 0                          0.0                          0.0
#
#    Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 0                          0.0                        0.0
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                            0.0                            0.0
#
# ...

# %% [raw]
# Item_Weight Item_Visibility   Item_MRP    Outlet_Establishment_Year  Item_Fat_Content_Regular Actual sales Predicted sales
#
# 9.30           0.016047          249.8092       1999                          1                 3735.1380   3496.7702859450146

# %%
def Sales_Prediction(Item_Weight,Item_Visibility,Item_MRP,Outlet_Establishment_Year,Location):
    user_df['Item_Weight']                  = Item_Weight
    user_df['Item_Visibility']              = Item_Visibility
    user_df['Item_MRP']                     = Item_MRP
    user_df['Outlet_Establishment_Year']    = Outlet_Establishment_Year
    user_df[Location] = 1
    res = pic_model.predict(user_df)[0][0]
    user_df.loc[0] = np.zeros(len(li_col))
    return np.round(res,3)

# %%
Sales_Prediction(9.30,0.016047,249.8092,1999,'Item_Fat_Content_Regular')
# Out:
# 3496.77
